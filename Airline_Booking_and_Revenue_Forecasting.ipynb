# %% [markdown]
# Airline Booking and Revenue Forecasting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing the required libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
from fbprophet import Prophet

#Importing the excel file
df1=pd.read_excel('/content/drive/MyDrive/FlyDubai.xlsx')

#Concatenating columns to one column
df1['Key'] = df1['Airline'] + "<<>>" + df1['Source']+ "<<>>"+df1['Destination']+ "<<>>"+df1['Product']+ "<<>>"+df1['Customer']

#Creating booking dataset
df2_book = df1[["Key", "Date", "Booking"]]

#Creating revenue dataset
df2_rev = df1[["Key", "Date", "Revenue"]]

#Renaming the columns for prophet library
booking = df2_book.rename(columns={'Date': 'ds', 'Booking':'y'})

#Creating empty dataframe to append with the output
forecast_outcome= pd.DataFrame()
#Grouping the dataframe with KEY column
grouped = booking.groupby('Key')
#Applying prophet model to each group
for var in grouped.groups:
    group = grouped.get_group(var)
    model = Prophet()
    model.fit(group)
    future = model.make_future_dataframe(periods=365)
    forecast = model.predict(future)
    forecast = forecast.rename(columns={'yhat': 'yhat_'+var})
    forecast_outcome= pd.merge(forecast_outcome, forecast.set_index('ds'), how='outer', left_index=True, right_index=True)
forecast_outcome= forecast_outcome[['yhat_' + var for var in grouped.groups.keys()]]
vAR_Outcome = pd.DataFrame(forecast_outcome).reset_index()

#Converting column to rows
Model_outcome = vAR_Outcome.melt(id_vars="ds", 
        var_name="cols", 
        value_name="Value")

#Replacing unwanted value
Model_outcome['cols'] = Model_outcome['cols'].str.replace('yhat_', '')

#Splitting the Key column to required 5 columns
Model_outcome[['Airline', 'Source', 'Destination', 'Product', 'Customer']] = Model_outcome['cols'].str.split('<<>>', 5, expand=True)

#Renaming the columns
Model_outcome.columns = ['Date_of_Journey', "Key", "Booking", 'Airline', 'Source', 'Destination', 'Product', 'Customer']

#Extracting only required columns
final_model_outcome = Model_outcome[['Date_of_Journey', 'Airline', 'Source', 'Destination', 'Product', 'Customer', 'Booking']]

#Exporting the file
final_model_outcome.to_csv("/content/drive/MyDrive/final_forecast_Booking.csv", index=False)

#Renaming the columns for prophet library
revenue = df2_rev.rename(columns={'Date': 'ds', 'Revenue':'y'})
#Creating empty dataframe to append with the output
forecast_outcome= pd.DataFrame()

#Grouping the dataframe with KEY column
grouped = revenue.groupby('Key')

#Applying prophet model to each group
for var in grouped.groups:
    group = grouped.get_group(var)
    model = Prophet()
    model.fit(group)
    future = model.make_future_dataframe(periods=365)
    forecast = model.predict(future)
    forecast = forecast.rename(columns={'yhat': 'yhat_'+var})
    forecast_outcome= pd.merge(forecast_outcome, forecast.set_index('ds'), how='outer', left_index=True, right_index=True)
forecast_outcome= forecast_outcome[['yhat_' + var for var in grouped.groups.keys()]]
vAR_Outcome = pd.DataFrame(forecast_outcome).reset_index()

#Converting column to rows
Model_outcome = vAR_Outcome.melt(id_vars="ds", 
        var_name="cols", 
        value_name="Value")

#Replacing unwanted value
Model_outcome['cols'] = Model_outcome['cols'].str.replace('yhat_', '')

#Splitting the Key column to required 5 columns
Model_outcome[['Airline', 'Source', 'Destination', 'Product', 'Customer']] = Model_outcome['cols'].str.split('<<>>', 5, expand=True)

#Renaming the columns
Model_outcome.columns = ['Date_of_Journey', "Key", "Revenue", 'Airline', 'Source', 'Destination', 'Product', 'Customer']

#Extracting only required columns
final_model_outcome = Model_outcome[['Date_of_Journey', 'Airline', 'Source', 'Destination', 'Product', 'Customer', 'Revenue']]

#Exporting the file
final_model_outcome.to_csv("/content/drive/MyDrive/final_forecast_revenue.csv", index=False)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: FutureWarning: Passing 'suffixes' which cause duplicate columns {'trend_upper_x', 'trend_x', 'multiplicative_terms_upper_x', 'trend_lower_x', 'weekly_upper_x', 'weekly_lower_x', 'additive_terms_upper_x', 'yhat_lower_x', 'additive_terms_lower_x', 'multiplicative_terms_lower_x', 'weekly_x', 'additive_terms_x', 'multiplicative_terms_x', 'yhat_upper_x'} in the result is deprecated and will raise a MergeError in a future version.
